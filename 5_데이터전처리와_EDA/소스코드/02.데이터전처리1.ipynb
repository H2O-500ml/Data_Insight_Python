# %% [markdown]
# # 02 데이터 전처리 1
#
# 1. 데이터를 임시로 로딩해서 데이터를 살펴봅니다.
# 2. 중복행이 있는지 살펴봅니다.
# 3. 데이터형식을 필요에 맞게 변경합니다. 특히 날짜형식
# 4. NaN와 이상치를 처리합니다.

# %% [markdown]
# ## 1. 데이터 '임시' 로딩
#
# **왜, 임시로 로딩을 할까?**
# 1. 데이터 타입들이 뭔지 모름
# 2. row가 몇 개인지 모름

# %%
import pandas as pd
import numpy as np

# %%
# nrows 파라미터를 이용하여 불러올 행의 수를 제한한다.
temp_loading = pd.read_csv(r'C:\Users\50008313\Python_Jupyter_Study\2기교육\5_데이터전처리와_EDA\샘플데이터\ade_sales.csv', nrows=1000,
                          engine='python')

# %%
# 항상 shape를 살펴보자.

temp_loading.shape
# Out:
# (32, 7)

# %%
temp_loading.head()
# Out:
#        Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 0  7/1/2016     Park     97      67           70      90.0   0.25
# 1  7/2/2016     Park     98      67           72      90.0   0.25
# 2  7/3/2016     Park    110      77           71     104.0   0.25
# 3  7/4/2016    Beach    134      99           76      98.0   0.25
# 4  7/5/2016    Beach    159     118           78     135.0   0.25

# %%
temp_loading.tail()
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 27  7/27/2016     Park    104      68           80      99.0   0.35
# 28  7/28/2016     Park     96      63           82      90.0   0.35
# 29  7/29/2016     Park    100      66           81      95.0   0.35
# 30  7/30/2016    Beach     88      57           82      81.0   0.35
# 31  7/31/2016    Beach     76      47           82      68.0   0.35

# %% [markdown]
# **아래의 코드 셀을 실행 시켜보자.**
# 이상한 점이 두 개 있다. 찾아서 확인하자.

# %%
temp_loading.describe()
# Out:
#             Lemon      Orange  Temperature    Leaflets      Price
# count   32.000000   32.000000    32.000000   31.000000  32.000000
# mean   116.156250   80.000000    78.968750  108.548387   0.354687
# std     25.823357   21.863211     4.067847   20.117718   0.113137
# min     71.000000   42.000000    70.000000   68.000000   0.250000
# 25%     98.000000   66.750000    77.000000   90.000000   0.250000
# 50%    113.500000   76.500000    80.500000  108.000000   0.350000
# 75%    131.750000   95.000000    82.000000  124.000000   0.500000
# max    176.000000  129.000000    84.000000  158.000000   0.500000

# %% [markdown]
# ## 2. 중복된 행을 대하는 태도.
#
# 1. 정말 진짜 아무 필요 없이 중복되었다? -> 지움.
# 2. '왜' 이런것이 수집되었는가. <- 매우 심각하게 고민해야 할 부분

# %%
temp_loading.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
temp_loading[temp_loading.duplicated()]
# Out:
#        Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 6  7/6/2016    Beach    103      69           82      90.0   0.25

# %%
temp_loading[4:9]
# Out:
#        Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 4  7/5/2016    Beach    159     118           78     135.0   0.25
# 5  7/6/2016    Beach    103      69           82      90.0   0.25
# 6  7/6/2016    Beach    103      69           82      90.0   0.25
# 7  7/7/2016    Beach    143     101           81     135.0   0.25
# 8  7/8/2017    Beach    123      86           82     113.0   0.25

# %%
# 중복 행 제거 : .drop_duplicates
temp_loading.drop_duplicates(inplace=True)

# %%
# 행 index를 reset : row가 제거되면, 항상 해주는 것이 좋다.
temp_loading = temp_loading.reset_index(drop=True)

# %%
temp_loading.duplicated().sum()
# Out:
# 0

# %%
temp_loading
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 0    7/1/2016     Park     97      67           70      90.0   0.25
# 1    7/2/2016     Park     98      67           72      90.0   0.25
# 2    7/3/2016     Park    110      77           71     104.0   0.25
# 3    7/4/2016    Beach    134      99           76      98.0   0.25
# 4    7/5/2016    Beach    159     118           78     135.0   0.25
# 5    7/6/2016    Beach    103      69           82      90.0   0.25
# 6    7/7/2016    Beach    143     101           81     135.0   0.25
# 7    7/8/2017    Beach    123      86           82     113.0   0.25
# 8    7/9/2016    Beach    134      95           80     126.0   0.25
# 9   7/10/2016    Beach    140      98           82     131.0   0.25
# 10  7/11/2016    Beach    162     120           83     135.0   0.25
# 11  7/12/2016    Beach    130      95           84      99.0   0.25
# 12  7/13/2016    Beach    109      75           77      99.0   0.25
# 13  7/14/2016    Beach    122      85           78     113.0   0.25
# 14  7/15/2016    Beach     98      62           75     108.0   0.50
# 15  7/16/2016    Beach     81      50           74      90.0   0.50
# 16  7/17/2016    Beach    115      76           77     126.0   0.50
# 17  7/18/2016     Park    131      92           81     122.0   0.50
# 18  7/19/2016     Park    122      85           78     113.0   0.50
# 19  7/20/2016     Park     71      42           70       NaN   0.50
# 20  7/21/2016     Park     83      50           77      90.0   0.50
# 21  7/22/2016     Park    112      75           80     108.0   0.50
# 22  7/23/2016     Park    120      82           81     117.0   0.50
# 23  7/24/2016     Park    121      82           82     117.0   0.50
# 24  7/25/2016     Park    156     113           84     135.0   0.50
# 25  7/26/2016     Park    176     129           83     158.0   0.35
# 26  7/27/2016     Park    104      68           80      99.0   0.35
# 27  7/28/2016     Park     96      63           82      90.0   0.35
# 28  7/29/2016     Park    100      66           81      95.0   0.35
# 29  7/30/2016    Beach     88      57           82      81.0   0.35
# 30  7/31/2016    Beach     76      47           82      68.0   0.35

# %% [markdown]
# ## 3. 날짜 형식 변경하기

# %%
temp_loading.dtypes
# Out:
# Date            object
# Location        object
# Lemon            int64
# Orange           int64
# Temperature      int64
# Leaflets       float64
# Price          float64
# dtype: object

# %%
# 코드 실행 후, 날짜 반드시 확인.  최악의 경우 기나긴 코딩/수작업이 필요하다.
temp_loading['Date'] = pd.to_datetime(temp_loading['Date'])
# temp_loading['Date'] = temp_loading['Date'].astype('datetime64')

# %%
temp_loading.dtypes
# Out:
# Date           datetime64[ns]
# Location               object
# Lemon                   int64
# Orange                  int64
# Temperature             int64
# Leaflets              float64
# Price                 float64
# dtype: object

# %% [markdown]
# ## 4. NaN 값을 다루는 방법

# %% [markdown]
# ### 4.1 NaN 찾기
# **.isnull = .isna**  <-- 둘은 같음. 그러나 isna를 더 많이 사용.

# %%
# 전체 값중 NaN여부 확인
temp_loading.isna()
# Out:
#      Date  Location  Lemon  Orange  Temperature  Leaflets  Price
# 0   False     False  False   False        False     False  False
# 1   False     False  False   False        False     False  False
# 2   False     False  False   False        False     False  False
# 3   False     False  False   False        False     False  False
# 4   False     False  False   False        False     False  False
# 5   False     False  False   False        False     False  False
# 6   False     False  False   False        False     False  False
# 7   False     False  False   False        False     False  False
# 8   False     False  False   False        False     False  False
# 9   False     False  False   False        False     False  False
# 10  False     False  False   False        False     False  False
# 11  False     False  False   False        False     False  False
# 12  False     False  False   False        False     False  False
# 13  False     False  False   False        False     False  False
# 14  False     False  False   False        False     False  False
# 15  False     False  False   False        False     False  False
# 16  False     False  False   False        False     False  False
# 17  False     False  False   False        False     False  False
# 18  False     False  False   False        False     False  False
# 19  False     False  False   False        False      True  False
# 20  False     False  False   False        False     False  False
# 21  False     False  False   False        False     False  False
# 22  False     False  False   False        False     False  False
# 23  False     False  False   False        False     False  False
# 24  False     False  False   False        False     False  False
# 25  False     False  False   False        False     False  False
# 26  False     False  False   False        False     False  False
# 27  False     False  False   False        False     False  False
# 28  False     False  False   False        False     False  False
# 29  False     False  False   False        False     False  False
# 30  False     False  False   False        False     False  False

# %%
# 칼럼(변수)중 NaN이 하나라도 있는지 여부 확인
temp_loading.isna().any()
# Out:
# Date           False
# Location       False
# Lemon          False
# Orange         False
# Temperature    False
# Leaflets        True
# Price          False
# dtype: bool

# %%
# 칼럼(변수)중 NaN이 몇개 있는지 확인
temp_loading.isna().sum()
# Out:
# Date           0
# Location       0
# Lemon          0
# Orange         0
# Temperature    0
# Leaflets       1
# Price          0
# dtype: int64

# %%
# 칼럼(변수)중 NaN이 있는 행번호 찾기 확인. any( 숫자) ==> 0 : 열단위, 1 : 행단위
temp_loading.isna().any(1)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# dtype: bool

# %%
# zero가 아닌 값이 있는 index 가져오기
temp_loading.isna().any(1).nonzero()
# Out:
# (array([19], dtype=int64),)

# %% [markdown]
# Leaflets의, 19번 row에 문제가 있다. 그 주변을 눈으로 확인하자.

# %%
temp_loading[['Leaflets']][15:24]
# Out:
#     Leaflets
# 15      90.0
# 16     126.0
# 17     122.0
# 18     113.0
# 19       NaN
# 20      90.0
# 21     108.0
# 22     117.0
# 23     117.0

# %% [markdown]
# ### 4.3 NaN 조치하기
# 중요한 변수라면 반드시 NaN을 조치해야 합니다.

# %% [markdown]
# **1) NaN이 들어간 행을 제거**
# 왠만하면 권장하지 않습니다.

# %%
#원본에서 하나 복사합시다.
temp2 = temp_loading.copy()

# %%
temp2[15:24]
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 15 2016-07-16    Beach     81      50           74      90.0    0.5
# 16 2016-07-17    Beach    115      76           77     126.0    0.5
# 17 2016-07-18     Park    131      92           81     122.0    0.5
# 18 2016-07-19     Park    122      85           78     113.0    0.5
# 19 2016-07-20     Park     71      42           70       NaN    0.5
# 20 2016-07-21     Park     83      50           77      90.0    0.5
# 21 2016-07-22     Park    112      75           80     108.0    0.5
# 22 2016-07-23     Park    120      82           81     117.0    0.5
# 23 2016-07-24     Park    121      82           82     117.0    0.5

# %%
temp2.dropna(inplace = True)

# %%
temp2[15:24]
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 15 2016-07-16    Beach     81      50           74      90.0    0.5
# 16 2016-07-17    Beach    115      76           77     126.0    0.5
# 17 2016-07-18     Park    131      92           81     122.0    0.5
# 18 2016-07-19     Park    122      85           78     113.0    0.5
# 20 2016-07-21     Park     83      50           77      90.0    0.5
# 21 2016-07-22     Park    112      75           80     108.0    0.5
# 22 2016-07-23     Park    120      82           81     117.0    0.5
# 23 2016-07-24     Park    121      82           82     117.0    0.5
# 24 2016-07-25     Park    156     113           84     135.0    0.5

# %% [markdown]
# **2) 특정값으로 채우기**

# %%
#원본에서 하나 복사합시다.
temp2 = temp_loading.copy()
temp2[15:24]
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 15 2016-07-16    Beach     81      50           74      90.0    0.5
# 16 2016-07-17    Beach    115      76           77     126.0    0.5
# 17 2016-07-18     Park    131      92           81     122.0    0.5
# 18 2016-07-19     Park    122      85           78     113.0    0.5
# 19 2016-07-20     Park     71      42           70       NaN    0.5
# 20 2016-07-21     Park     83      50           77      90.0    0.5
# 21 2016-07-22     Park    112      75           80     108.0    0.5
# 22 2016-07-23     Park    120      82           81     117.0    0.5
# 23 2016-07-24     Park    121      82           82     117.0    0.5

# %%
# 0으로 채우기
temp2.fillna(0)

# 0으로 채우고 저장하려면  inplace = True 를 포함시켜야 합니다.
# temp_ma.fillna(0, inplace = True)
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 0  2016-07-01     Park     97      67           70      90.0   0.25
# 1  2016-07-02     Park     98      67           72      90.0   0.25
# 2  2016-07-03     Park    110      77           71     104.0   0.25
# 3  2016-07-04    Beach    134      99           76      98.0   0.25
# 4  2016-07-05    Beach    159     118           78     135.0   0.25
# 5  2016-07-06    Beach    103      69           82      90.0   0.25
# 6  2016-07-07    Beach    143     101           81     135.0   0.25
# 7  2017-07-08    Beach    123      86           82     113.0   0.25
# 8  2016-07-09    Beach    134      95           80     126.0   0.25
# 9  2016-07-10    Beach    140      98           82     131.0   0.25
# 10 2016-07-11    Beach    162     120           83     135.0   0.25
# 11 2016-07-12    Beach    130      95           84      99.0   0.25
# 12 2016-07-13    Beach    109      75           77      99.0   0.25
# 13 2016-07-14    Beach    122      85           78     113.0   0.25
# 14 2016-07-15    Beach     98      62           75     108.0   0.50
# 15 2016-07-16    Beach     81      50           74      90.0   0.50
# 16 2016-07-17    Beach    115      76           77     126.0   0.50
# 17 2016-07-18     Park    131      92           81     122.0   0.50
# 18 2016-07-19     Park    122      85           78     113.0   0.50
# 19 2016-07-20     Park     71      42           70       0.0   0.50
# 20 2016-07-21     Park     83      50           77      90.0   0.50
# 21 2016-07-22     Park    112      75           80     108.0   0.50
# 22 2016-07-23     Park    120      82           81     117.0   0.50
# 23 2016-07-24     Park    121      82           82     117.0   0.50
# 24 2016-07-25     Park    156     113           84     135.0   0.50
# 25 2016-07-26     Park    176     129           83     158.0   0.35
# 26 2016-07-27     Park    104      68           80      99.0   0.35
# 27 2016-07-28     Park     96      63           82      90.0   0.35
# 28 2016-07-29     Park    100      66           81      95.0   0.35
# 29 2016-07-30    Beach     88      57           82      81.0   0.35
# 30 2016-07-31    Beach     76      47           82      68.0   0.35

# %%
#직전값으로 채우기
temp2.fillna(method = 'ffill')
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 0  2016-07-01     Park     97      67           70      90.0   0.25
# 1  2016-07-02     Park     98      67           72      90.0   0.25
# 2  2016-07-03     Park    110      77           71     104.0   0.25
# 3  2016-07-04    Beach    134      99           76      98.0   0.25
# 4  2016-07-05    Beach    159     118           78     135.0   0.25
# 5  2016-07-06    Beach    103      69           82      90.0   0.25
# 6  2016-07-07    Beach    143     101           81     135.0   0.25
# 7  2017-07-08    Beach    123      86           82     113.0   0.25
# 8  2016-07-09    Beach    134      95           80     126.0   0.25
# 9  2016-07-10    Beach    140      98           82     131.0   0.25
# 10 2016-07-11    Beach    162     120           83     135.0   0.25
# 11 2016-07-12    Beach    130      95           84      99.0   0.25
# 12 2016-07-13    Beach    109      75           77      99.0   0.25
# 13 2016-07-14    Beach    122      85           78     113.0   0.25
# 14 2016-07-15    Beach     98      62           75     108.0   0.50
# 15 2016-07-16    Beach     81      50           74      90.0   0.50
# 16 2016-07-17    Beach    115      76           77     126.0   0.50
# 17 2016-07-18     Park    131      92           81     122.0   0.50
# 18 2016-07-19     Park    122      85           78     113.0   0.50
# 19 2016-07-20     Park     71      42           70     113.0   0.50
# 20 2016-07-21     Park     83      50           77      90.0   0.50
# 21 2016-07-22     Park    112      75           80     108.0   0.50
# 22 2016-07-23     Park    120      82           81     117.0   0.50
# 23 2016-07-24     Park    121      82           82     117.0   0.50
# 24 2016-07-25     Park    156     113           84     135.0   0.50
# 25 2016-07-26     Park    176     129           83     158.0   0.35
# 26 2016-07-27     Park    104      68           80      99.0   0.35
# 27 2016-07-28     Park     96      63           82      90.0   0.35
# 28 2016-07-29     Park    100      66           81      95.0   0.35
# 29 2016-07-30    Beach     88      57           82      81.0   0.35
# 30 2016-07-31    Beach     76      47           82      68.0   0.35

# %%
#직후 값으로 채우기
temp2.fillna(method = 'bfill')
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 0  2016-07-01     Park     97      67           70      90.0   0.25
# 1  2016-07-02     Park     98      67           72      90.0   0.25
# 2  2016-07-03     Park    110      77           71     104.0   0.25
# 3  2016-07-04    Beach    134      99           76      98.0   0.25
# 4  2016-07-05    Beach    159     118           78     135.0   0.25
# 5  2016-07-06    Beach    103      69           82      90.0   0.25
# 6  2016-07-07    Beach    143     101           81     135.0   0.25
# 7  2017-07-08    Beach    123      86           82     113.0   0.25
# 8  2016-07-09    Beach    134      95           80     126.0   0.25
# 9  2016-07-10    Beach    140      98           82     131.0   0.25
# 10 2016-07-11    Beach    162     120           83     135.0   0.25
# 11 2016-07-12    Beach    130      95           84      99.0   0.25
# 12 2016-07-13    Beach    109      75           77      99.0   0.25
# 13 2016-07-14    Beach    122      85           78     113.0   0.25
# 14 2016-07-15    Beach     98      62           75     108.0   0.50
# 15 2016-07-16    Beach     81      50           74      90.0   0.50
# 16 2016-07-17    Beach    115      76           77     126.0   0.50
# 17 2016-07-18     Park    131      92           81     122.0   0.50
# 18 2016-07-19     Park    122      85           78     113.0   0.50
# 19 2016-07-20     Park     71      42           70      90.0   0.50
# 20 2016-07-21     Park     83      50           77      90.0   0.50
# 21 2016-07-22     Park    112      75           80     108.0   0.50
# 22 2016-07-23     Park    120      82           81     117.0   0.50
# 23 2016-07-24     Park    121      82           82     117.0   0.50
# 24 2016-07-25     Park    156     113           84     135.0   0.50
# 25 2016-07-26     Park    176     129           83     158.0   0.35
# 26 2016-07-27     Park    104      68           80      99.0   0.35
# 27 2016-07-28     Park     96      63           82      90.0   0.35
# 28 2016-07-29     Park    100      66           81      95.0   0.35
# 29 2016-07-30    Beach     88      57           82      81.0   0.35
# 30 2016-07-31    Beach     76      47           82      68.0   0.35

# %% [markdown]
# **3) 의미있게 채우기**
#
#     * 평균
#     * 근처만의 평균 (ex> 과거2일 ~ 다음 2일)
#     * 최빈값, 중앙값 등
#     * 그 날과 같은/비슷한 feature를 갖는 날들의 평균
#
# [fillna 링크 참고](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html)

# %% [markdown]
# **예시1 : 과거 2일 ~ 다음 2일로 평균 채워 넣기**
#
# * 채워 넣고 나서, 문제점이 있는지 찾아봅시다.

# %%
# 일단 복사해 놓고 시작합시다.
temp2 = temp_loading.copy()

# %%
temp2[17:22]
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 17 2016-07-18     Park    131      92           81     122.0    0.5
# 18 2016-07-19     Park    122      85           78     113.0    0.5
# 19 2016-07-20     Park     71      42           70       NaN    0.5
# 20 2016-07-21     Park     83      50           77      90.0    0.5
# 21 2016-07-22     Park    112      75           80     108.0    0.5

# %%
# 우리는 아래와 같은 방법으로 진행합니다.
temp2.loc[19, 'Leaflets'] = temp_loading.loc[17:22, 'Leaflets'].mean()

# %%
temp2[17:22]
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 17 2016-07-18     Park    131      92           81     122.0    0.5
# 18 2016-07-19     Park    122      85           78     113.0    0.5
# 19 2016-07-20     Park     71      42           70     110.0    0.5
# 20 2016-07-21     Park     83      50           77      90.0    0.5
# 21 2016-07-22     Park    112      75           80     108.0    0.5

# %% [markdown]
# **실습1 : 전체 평균으로 채워 넣기**

# %%
temp_ta = temp_loading.copy()

# %%
temp_ta.loc[19, 'Leaflets'] = temp_ta['Leaflets'].mean()
temp_ta[17:22]
# Out:
#          Date Location  Lemon  Orange  Temperature    Leaflets  Price
# 17 2016-07-18     Park    131      92           81  122.000000    0.5
# 18 2016-07-19     Park    122      85           78  113.000000    0.5
# 19 2016-07-20     Park     71      42           70  109.166667    0.5
# 20 2016-07-21     Park     83      50           77   90.000000    0.5
# 21 2016-07-22     Park    112      75           80  108.000000    0.5

# %%
temp_ta['Leaflets'] = temp_ta['Leaflets'].round()
temp_ta[17:22]
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 17 2016-07-18     Park    131      92           81     122.0    0.5
# 18 2016-07-19     Park    122      85           78     113.0    0.5
# 19 2016-07-20     Park     71      42           70     109.0    0.5
# 20 2016-07-21     Park     83      50           77      90.0    0.5
# 21 2016-07-22     Park    112      75           80     108.0    0.5

# %% [markdown]
# **실습2 : 중앙값으로 채워 넣기**
#
# 중앙값(median)을 구하는 방법은 여러가지 있습니다. 찾아보세요~!

# %%
temp_tm = temp_loading.copy()

# %%
temp_ta.loc[19, 'Leaflets'] = temp_ta['Leaflets'].median()
temp_ta[17:22]
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 17 2016-07-18     Park    131      92           81     122.0    0.5
# 18 2016-07-19     Park    122      85           78     113.0    0.5
# 19 2016-07-20     Park     71      42           70     108.0    0.5
# 20 2016-07-21     Park     83      50           77      90.0    0.5
# 21 2016-07-22     Park    112      75           80     108.0    0.5

# %% [markdown]
# **실습3 : 그 날과 같은/비슷한 feature를 갖는 날들의 평균으로 채워 넣기**
#
# * 코드 한 줄로 깔끔하게 되는 방법 없습니다.
# * 엑셀 수작업, SQL 쿼리, 판다스 무엇을 이용해도 좋습니다.
# * 다만, **어떤 방식으로, 왜 그렇게 했는지 설명 가능해야 합니다.**

# %%
temp_knn = temp_loading.copy()

# %%
temp_knn
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 0  2016-07-01     Park     97      67           70      90.0   0.25
# 1  2016-07-02     Park     98      67           72      90.0   0.25
# 2  2016-07-03     Park    110      77           71     104.0   0.25
# 3  2016-07-04    Beach    134      99           76      98.0   0.25
# 4  2016-07-05    Beach    159     118           78     135.0   0.25
# 5  2016-07-06    Beach    103      69           82      90.0   0.25
# 6  2016-07-07    Beach    143     101           81     135.0   0.25
# 7  2017-07-08    Beach    123      86           82     113.0   0.25
# 8  2016-07-09    Beach    134      95           80     126.0   0.25
# 9  2016-07-10    Beach    140      98           82     131.0   0.25
# 10 2016-07-11    Beach    162     120           83     135.0   0.25
# 11 2016-07-12    Beach    130      95           84      99.0   0.25
# 12 2016-07-13    Beach    109      75           77      99.0   0.25
# 13 2016-07-14    Beach    122      85           78     113.0   0.25
# 14 2016-07-15    Beach     98      62           75     108.0   0.50
# 15 2016-07-16    Beach     81      50           74      90.0   0.50
# 16 2016-07-17    Beach    115      76           77     126.0   0.50
# 17 2016-07-18     Park    131      92           81     122.0   0.50
# 18 2016-07-19     Park    122      85           78     113.0   0.50
# 19 2016-07-20     Park     71      42           70       NaN   0.50
# 20 2016-07-21     Park     83      50           77      90.0   0.50
# 21 2016-07-22     Park    112      75           80     108.0   0.50
# 22 2016-07-23     Park    120      82           81     117.0   0.50
# 23 2016-07-24     Park    121      82           82     117.0   0.50
# 24 2016-07-25     Park    156     113           84     135.0   0.50
# 25 2016-07-26     Park    176     129           83     158.0   0.35
# 26 2016-07-27     Park    104      68           80      99.0   0.35
# 27 2016-07-28     Park     96      63           82      90.0   0.35
# 28 2016-07-29     Park    100      66           81      95.0   0.35
# 29 2016-07-30    Beach     88      57           82      81.0   0.35
# 30 2016-07-31    Beach     76      47           82      68.0   0.35

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(temp_knn)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     376             try:
# --> 377                 values, tz = conversion.datetime_to_datetime64(arg)
#     378                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_converter.py in _convert_1d(values, unit, axis)
#     331             try:
# --> 332                 values = tools.to_datetime(values)
#     333                 if isinstance(values, Index):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     466         else:
# --> 467             result = _convert_listlike(arg, box, format)
#     468     else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     379             except (ValueError, TypeError):
# --> 380                 raise e
#     381
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     367                     yearfirst=yearfirst,
# --> 368                     require_iso8601=require_iso8601
#     369                 )
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1355     else:
# -> 1356         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1357
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     647         if res is None:
# --> 648             raise ValueError("Unknown string format:", timestr)
#     649
#
# ValueError: ('Unknown string format:', 'Park')
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-ceb178180020> in <module>
# ----> 1 plt.plot(temp_knn)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1610
#    1611         for line in self._get_lines(*args, **kwargs):
# -> 1612             self.add_line(line)
#    1613             lines.append(line)
#    1614
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_base.py in add_line(self, line)
#    1893             line.set_clip_path(self.patch)
#    1894
# -> 1895         self._update_line_limits(line)
#    1896         if not line.get_label():
#    1897             line.set_label('_line%d' % len(self.lines))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _update_line_limits(self, line)
#    1915         Figures out the data limit of the given line, updating self.dataLim.
#    1916         """
# -> 1917         path = line.get_path()
#    1918         if path.vertices.size == 0:
#    1919             return
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\lines.py in get_path(self)
#     943         """
#     944         if self._invalidy or self._invalidx:
# --> 945             self.recache()
#     946         return self._path
#     947
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     642             x = self._x
#     643         if always or self._invalidy:
# --> 644             yconv = self.convert_yunits(self._yorig)
#     645             y = _to_unmasked_float_array(yconv).ravel()
#     646         else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\artist.py in convert_yunits(self, y)
#     193         if ax is None or ax.yaxis is None:
#     194             return y
# --> 195         return ax.yaxis.convert_units(y)
#     196
#     197     @property
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1528             return x
#    1529
# -> 1530         ret = self.converter.convert(x, self.units, self)
#    1531         return ret
#    1532
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_converter.py in convert(values, unit, axis)
#     299                       for v in values]
#     300         else:
# --> 301             values = DatetimeConverter._convert_1d(values, unit, axis)
#     302         return values
#     303
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_converter.py in _convert_1d(values, unit, axis)
#     336                     values = [_dt_to_float_ordinal(x) for x in values]
#     337             except Exception:
# --> 338                 values = _dt_to_float_ordinal(values)
#     339
#     340         return values
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_converter.py in _dt_to_float_ordinal(dt)
#     284         base = dates.epoch2num(dt.asi8 / 1.0E9)
#     285     else:
# --> 286         base = dates.date2num(dt)
#     287     return base
#     288
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\dates.py in date2num(d)
#     426         if not d.size:
#     427             return d
# --> 428         return _to_ordinalf_np_vectorized(d)
#     429
#     430
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\function_base.py in __call__(self, *args, **kwargs)
#    1970             vargs.extend([kwargs[_n] for _n in names])
#    1971
# -> 1972         return self._vectorize_call(func=func, args=vargs)
#    1973
#    1974     def _get_ufunc_and_otypes(self, func, args):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\function_base.py in _vectorize_call(self, func, args)
#    2040             res = func()
#    2041         else:
# -> 2042             ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2043
#    2044             # Convert args to object arrays first
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\function_base.py in _get_ufunc_and_otypes(self, func, args)
#    2000
#    2001             inputs = [arg.flat[0] for arg in args]
# -> 2002             outputs = func(*inputs)
#    2003
#    2004             # Performance note: profiling indicates that -- for simple
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\dates.py in _to_ordinalf(dt)
#     227         tzi = UTC
#     228
# --> 229     base = float(dt.toordinal())
#     230
#     231     # If it's sufficiently datetime-like, it will have a `date()` method
#
# AttributeError: 'str' object has no attribute 'toordinal'

# %% [markdown]
# **실습4 : 또 다른 아이디어가 있다면 시도해보세요**

# %%
temp_another = temp_loading.copy()

# %% [markdown]
# ## 일단, 저장.
#
# 아직 끝나지 않았습니다.^^
# temp2를 저장했지만, 자기가 원하는 다른 것을 저장해도 좋다.

# %%
temp2.to_csv('ade_temp1.csv', index=False)

# %% [markdown]
# ### 4.3 NaN을 채우는 또다른 사례

# %% [markdown]
# titanic 데이터셋을 가지고 진행합니다.

# %%
# 데이터 셋 불러옵니다.
ti = pd.read_csv(r'C:\Users\50008313\Python_Jupyter_Study\2기교육\5_데이터전처리와_EDA\샘플데이터\titanic_simple.csv', engine='python')

# %%
# 데이터셋을 가져온 후에 기본적으로 점검해야 할 사항들을 살펴봅시다.

# Shape
ti.shape

# 상위, 하위 데이터


# 칼럼별 데이터타입


# describe()


# 칼럼별 NaN 갯수 확인

ti.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# Fare             0
# Embarked         2
# dtype: int64

# %% [markdown]
# 칼럼별 NaN의 갯수를 확인하셨지요?
# Age는 중요한 변수일텐데, 결측치가 많습니다.
# 어떻게 처리하면 좋을까요?
# ① 제거?
# ② 값채우기?
# ③ 데이터셋 분리하여 각각 모델링?

# %% [markdown]
# 우리는 값을 채우는 방법을 적용해 봅시다.
# 그렇다면 값을 어떻게 채우면 좋을까요?

# %%
ti2 = ti.copy()

# %%
# 새로운 칼럼을 만들고 빈 값으로 채웁니다.
ti2['Title'] = ''

# %%
ti2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age     Fare  \
# 0                            Braund, Mr. Owen Harris    male  22.0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                             Heikkinen, Miss. Laina  female  26.0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                           Allen, Mr. William Henry    male  35.0   8.0500
#
#        Embarked Title
# 0  Southhampton
# 1     Cherbourg
# 2  Southhampton
# 3  Southhampton
# 4  Southhampton

# %%
ti2.Name.str.contains('Mr[.]').head(10) # [.]은 반드시 .이 포함되어야 한다는 것. Mrs. 등과 구분하기 위함.
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# 7    False
# 8    False
# 9    False
# Name: Name, dtype: bool

# %% [markdown]
# Mr[.] <== []는 왜 붙였을까요?
# 이에 대해서 더 많은 정보가 궁금하시다면, [정규표현식](https://wikidocs.net/4308) 을 학습하세요.

# %%
#이름에 'Mr.'이 들어간 사람들 다 보여줘~
ti2.loc[ti2.Name.str.contains('Mr[.]')]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 0              1         0       3               Braund, Mr. Owen Harris
# 4              5         0       3              Allen, Mr. William Henry
# 5              6         0       3                      Moran, Mr. James
# 6              7         0       1               McCarthy, Mr. Timothy J
# 12            13         0       3        Saundercock, Mr. William Henry
# 13            14         0       3           Andersson, Mr. Anders Johan
# 17            18         1       2          Williams, Mr. Charles Eugene
# 20            21         0       2                  Fynney, Mr. Joseph J
# 21            22         1       2                 Beesley, Mr. Lawrence
# 23            24         1       1          Sloper, Mr. William Thompson
# 26            27         0       3               Emir, Mr. Farred Chehab
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 29            30         0       3                   Todoroff, Mr. Lalio
# 33            34         0       2                 Wheadon, Mr. Edward H
# 34            35         0       1               Meyer, Mr. Edgar Joseph
# 35            36         0       1        Holverson, Mr. Alexander Oskar
# 36            37         1       3                      Mamee, Mr. Hanna
# 37            38         0       3              Cann, Mr. Ernest Charles
# 42            43         0       3                   Kraeff, Mr. Theodor
# 45            46         0       3              Rogers, Mr. William John
# 46            47         0       3                     Lennon, Mr. Denis
# 48            49         0       3                   Samaan, Mr. Youssef
# 51            52         0       3          Nosworthy, Mr. Richard Cater
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 55            56         1       1                     Woolner, Mr. Hugh
# 57            58         0       3                   Novel, Mr. Mansouer
# 60            61         0       3                 Sirayanian, Mr. Orsen
# 62            63         0       1           Harris, Mr. Henry Birkhardt
# 64            65         0       1                 Stewart, Mr. Albert A
# 67            68         0       3              Crease, Mr. Ernest James
# ..           ...       ...     ...                                   ...
# 836          837         0       3                      Pasic, Mr. Jakob
# 837          838         0       3                   Sirota, Mr. Maurice
# 838          839         1       3                       Chip, Mr. Chang
# 839          840         1       1                  Marechal, Mr. Pierre
# 840          841         0       3           Alhomaki, Mr. Ilmari Rudolf
# 841          842         0       2              Mudd, Mr. Thomas Charles
# 843          844         0       3            Lemberopolous, Mr. Peter L
# 844          845         0       3                   Culumovic, Mr. Jeso
# 845          846         0       3                   Abbing, Mr. Anthony
# 846          847         0       3              Sage, Mr. Douglas Bullen
# 847          848         0       3                    Markoff, Mr. Marin
# 851          852         0       3                   Svensson, Mr. Johan
# 857          858         1       1                Daly, Mr. Peter Denis
# 859          860         0       3                      Razi, Mr. Raihed
# 860          861         0       3               Hansen, Mr. Claus Peter
# 861          862         0       2           Giles, Mr. Frederick Edward
# 864          865         0       2                Gill, Mr. John William
# 867          868         0       1  Roebling, Mr. Washington Augustus II
# 868          869         0       3           van Melkebeke, Mr. Philemon
# 870          871         0       3                     Balkic, Mr. Cerin
# 872          873         0       1              Carlsson, Mr. Frans Olof
# 873          874         0       3           Vander Cruyssen, Mr. Victor
# 876          877         0       3         Gustafsson, Mr. Alfred Ossian
# 877          878         0       3                  Petroff, Mr. Nedelio
# 878          879         0       3                    Laleff, Mr. Kristo
# 881          882         0       3                    Markun, Mr. Johann
# 883          884         0       2         Banfield, Mr. Frederick James
# 884          885         0       3                Sutehall, Mr. Henry Jr
# 889          890         1       1                 Behr, Mr. Karl Howell
# 890          891         0       3                   Dooley, Mr. Patrick
#
#       Sex   Age      Fare      Embarked Title
# 0    male  22.0    7.2500  Southhampton
# 4    male  35.0    8.0500  Southhampton
# 5    male   NaN    8.4583    Queenstown
# 6    male  54.0   51.8625  Southhampton
# 12   male  20.0    8.0500  Southhampton
# 13   male  39.0   31.2750  Southhampton
# 17   male   NaN   13.0000  Southhampton
# 20   male  35.0   26.0000  Southhampton
# 21   male  34.0   13.0000  Southhampton
# 23   male  28.0   35.5000  Southhampton
# 26   male   NaN    7.2250     Cherbourg
# 27   male  19.0  263.0000  Southhampton
# 29   male   NaN    7.8958  Southhampton
# 33   male  66.0   10.5000  Southhampton
# 34   male  28.0   82.1708     Cherbourg
# 35   male  42.0   52.0000  Southhampton
# 36   male   NaN    7.2292     Cherbourg
# 37   male  21.0    8.0500  Southhampton
# 42   male   NaN    7.8958     Cherbourg
# 45   male   NaN    8.0500  Southhampton
# 46   male   NaN   15.5000    Queenstown
# 48   male   NaN   21.6792     Cherbourg
# 51   male  21.0    7.8000  Southhampton
# 54   male  65.0   61.9792     Cherbourg
# 55   male   NaN   35.5000  Southhampton
# 57   male  28.5    7.2292     Cherbourg
# 60   male  22.0    7.2292     Cherbourg
# 62   male  45.0   83.4750  Southhampton
# 64   male   NaN   27.7208     Cherbourg
# 67   male  19.0    8.1583  Southhampton
# ..    ...   ...       ...           ...   ...
# 836  male  21.0    8.6625  Southhampton
# 837  male   NaN    8.0500  Southhampton
# 838  male  32.0   56.4958  Southhampton
# 839  male   NaN   29.7000     Cherbourg
# 840  male  20.0    7.9250  Southhampton
# 841  male  16.0   10.5000  Southhampton
# 843  male  34.5    6.4375     Cherbourg
# 844  male  17.0    8.6625  Southhampton
# 845  male  42.0    7.5500  Southhampton
# 846  male   NaN   69.5500  Southhampton
# 847  male  35.0    7.8958     Cherbourg
# 851  male  74.0    7.7750  Southhampton
# 857  male  51.0   26.5500  Southhampton
# 859  male   NaN    7.2292     Cherbourg
# 860  male  41.0   14.1083  Southhampton
# 861  male  21.0   11.5000  Southhampton
# 864  male  24.0   13.0000  Southhampton
# 867  male  31.0   50.4958  Southhampton
# 868  male   NaN    9.5000  Southhampton
# 870  male  26.0    7.8958  Southhampton
# 872  male  33.0    5.0000  Southhampton
# 873  male  47.0    9.0000  Southhampton
# 876  male  20.0    9.8458  Southhampton
# 877  male  19.0    7.8958  Southhampton
# 878  male   NaN    7.8958  Southhampton
# 881  male  33.0    7.8958  Southhampton
# 883  male  28.0   10.5000  Southhampton
# 884  male  25.0    7.0500  Southhampton
# 889  male  26.0   30.0000     Cherbourg
# 890  male  32.0    7.7500    Queenstown
#
# [517 rows x 9 columns]

# %%
# 이름에 'Mr.'이 들어간 사람들의 Title에 'Mr'이라고 호칭을 넣어주자
ti2.loc[ti2.Name.str.contains('Mr[.]'), 'Title'] = 'Mr'

# %%
ti2.loc[ti2.Name.str.contains('Mr[.]')].head()
# Out:
#     PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0             1         0       3         Braund, Mr. Owen Harris  male  22.0
# 4             5         0       3        Allen, Mr. William Henry  male  35.0
# 5             6         0       3                Moran, Mr. James  male   NaN
# 6             7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 12           13         0       3  Saundercock, Mr. William Henry  male  20.0
#
#        Fare      Embarked Title
# 0    7.2500  Southhampton    Mr
# 4    8.0500  Southhampton    Mr
# 5    8.4583    Queenstown    Mr
# 6   51.8625  Southhampton    Mr
# 12   8.0500  Southhampton    Mr

# %%
# 호칭이 Mr인 사람들의 평균 나이
mr_avg = ti2.loc[ti2.Title=='Mr' , "Age"].mean()

# %%
# 호칭이 Mr인 사람들 중 Age가 Na(NaN)인 사람들에게, Mr인 사람들의 평균 나이로 채우기
ti2.loc[(ti2.Title=='Mr') & (ti2['Age'].isna()), "Age"] = mr_avg

# %%
ti2.loc[(ti2.Title=='Mr') & (ti2['Age'].isna())]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, Fare, Embarked, Title]
# Index: []

# %% [markdown]
# ### 실습
# 이제 나이가 NaN인 사람들의 호칭을 살펴보고, 위와 동일한 절차로 Age의 NaN값을 처리하시오.

# %%
# 1. ti를 ti2로 복사하시오

ti2=ti.copy()

# %%
# 2. ti2의 이름에서 호칭을 분리하여 Title에 담으시오.

ti2['Title']=''
ti2.loc[ti2.Name.str.contains('Mr[.]'), 'Title'] = 'Mr'
ti2.loc[ti2.Name.str.contains('Mrs[.]'), 'Title'] = 'Mrs'
ti2.loc[ti2.Name.str.contains('Miss'), 'Title'] = 'Miss'
ti2.loc[ti2.Name.str.contains('Master[.]'), 'Title'] = 'Master'
ti2.loc[ti2.Name.str.contains('Dr[.]'), 'Title'] = 'Dr'
ti2[ti2['Title']=='']
# Out:
#      PassengerId  Survived  Pclass  \
# 30            31         0       1
# 149          150         0       2
# 150          151         0       2
# 249          250         0       2
# 369          370         1       1
# 443          444         1       2
# 449          450         1       1
# 536          537         0       1
# 556          557         1       1
# 599          600         1       1
# 626          627         0       2
# 641          642         1       1
# 647          648         1       1
# 694          695         0       1
# 710          711         1       1
# 745          746         0       1
# 759          760         1       1
# 822          823         0       1
# 848          849         0       2
# 886          887         0       2
#
#                                                   Name     Sex   Age     Fare  \
# 30                            Uruchurtu, Don. Manuel E    male  40.0  27.7208
# 149                  Byles, Rev. Thomas Roussel Davids    male  42.0  13.0000
# 150                         Bateman, Rev. Robert James    male  51.0  12.5250
# 249                      Carter, Rev. Ernest Courtenay    male  54.0  26.0000
# 369                      Aubart, Mme. Leontine Pauline  female  24.0  69.3000
# 443                          Reynaldo, Ms. Encarnacion  female  28.0  13.0000
# 449                     Peuchen, Major. Arthur Godfrey    male  52.0  30.5000
# 536                  Butt, Major. Archibald Willingham    male  45.0  26.5500
# 556  Duff Gordon, Lady. (Lucille Christiana Sutherl...  female  48.0  39.6000
# 599       Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")    male  49.0  56.9292
# 626                     Kirkland, Rev. Charles Leonard    male  57.0  12.3500
# 641                               Sagesser, Mlle. Emma  female  24.0  69.3000
# 647                Simonius-Blumer, Col. Oberst Alfons    male  56.0  35.5000
# 694                                    Weir, Col. John    male  60.0  26.5500
# 710   Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")  female  24.0  49.5042
# 745                       Crosby, Capt. Edward Gifford    male  70.0  71.0000
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.0  86.5000
# 822                    Reuchlin, Jonkheer. John George    male  38.0   0.0000
# 848                                  Harper, Rev. John    male  28.0  33.0000
# 886                              Montvila, Rev. Juozas    male  27.0  13.0000
#
#          Embarked Title
# 30      Cherbourg
# 149  Southhampton
# 150  Southhampton
# 249  Southhampton
# 369     Cherbourg
# 443  Southhampton
# 449  Southhampton
# 536  Southhampton
# 556     Cherbourg
# 599     Cherbourg
# 626    Queenstown
# 641     Cherbourg
# 647     Cherbourg
# 694  Southhampton
# 710     Cherbourg
# 745  Southhampton
# 759  Southhampton
# 822  Southhampton
# 848  Southhampton
# 886  Southhampton

# %%
# 3. Age를 반올림(.round())하여 Age2에 담으시오.

ti2['Age2']=ti2['Age'].round()
ti2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age     Fare  \
# 0                            Braund, Mr. Owen Harris    male  22.0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                             Heikkinen, Miss. Laina  female  26.0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                           Allen, Mr. William Henry    male  35.0   8.0500
#
#        Embarked Title  Age2
# 0  Southhampton    Mr  22.0
# 1     Cherbourg   Mrs  38.0
# 2  Southhampton  Miss  26.0
# 3  Southhampton   Mrs  35.0
# 4  Southhampton    Mr  35.0

# %%
# 4. 호칭별 Age2의 중앙값(median())을 구하시오.
mr_med = ti2.loc[ti2.Title=='Mr','Age2'].median()
mrs_med = ti2.loc[ti2.Title=='Mrs','Age2'].median()
miss_med = ti2.loc[ti2.Title=='Miss','Age2'].median()
master_med = ti2.loc[ti2.Title=='Master','Age2'].median()
dr_med = ti2.loc[ti2.Title=='Dr','Age2'].median()
print(mr_med)
print(mrs_med)
print(miss_med)
print(master_med)
print(dr_med)
# Out:
# 30.0
# 35.0
# 21.0
# 3.5
# 46.5

# %%
# 5. Age2가 NaN에 대해서 호칭별 중앙값으로 대체하시오.
ti2.loc[(ti2.Title == 'Mr') & ti2['Age'].isna(), 'Age2'] = mr_med
ti2.loc[(ti2.Title == 'Mrs') & ti2['Age'].isna(), 'Age2'] = mrs_med
ti2.loc[(ti2.Title == 'Miss') & ti2['Age'].isna(), 'Age2'] = miss_med
ti2.loc[(ti2.Title == 'Master') & ti2['Age'].isna(), 'Age2'] = master_med
ti2.loc[(ti2.Title == 'Dr') & ti2['Age'].isna(), 'Age2'] = dr_med

ti2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# 5                                     Moran, Mr. James    male   NaN
# 6                              McCarthy, Mr. Timothy J    male  54.0
# 7                       Palsson, Master. Gosta Leonard    male   2.0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0
# 11                            Bonnell, Miss. Elizabeth  female  58.0
# 12                      Saundercock, Mr. William Henry    male  20.0
# 13                         Andersson, Mr. Anders Johan    male  39.0
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# 16                                Rice, Master. Eugene    male   2.0
# 17                        Williams, Mr. Charles Eugene    male   NaN
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0
# 19                             Masselmani, Mrs. Fatima  female   NaN
# 20                                Fynney, Mr. Joseph J    male  35.0
# 21                               Beesley, Mr. Lawrence    male  34.0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0
# 23                        Sloper, Mr. William Thompson    male  28.0
# 24                       Palsson, Miss. Torborg Danira  female   8.0
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0
# 26                             Emir, Mr. Farred Chehab    male   NaN
# 27                      Fortune, Mr. Charles Alexander    male  19.0
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female   NaN
# 29                                 Todoroff, Mr. Lalio    male   NaN
# ..                                                 ...     ...   ...
# 861                        Giles, Mr. Frederick Edward    male  21.0
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN
# 864                             Gill, Mr. John William    male  24.0
# 865                           Bystrom, Mrs. (Karolina)  female  42.0
# 866                       Duran y More, Miss. Asuncion  female  27.0
# 867               Roebling, Mr. Washington Augustus II    male  31.0
# 868                        van Melkebeke, Mr. Philemon    male   NaN
# 869                    Johnson, Master. Harold Theodor    male   4.0
# 870                                  Balkic, Mr. Cerin    male  26.0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0
# 872                           Carlsson, Mr. Frans Olof    male  33.0
# 873                        Vander Cruyssen, Mr. Victor    male  47.0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0
# 876                      Gustafsson, Mr. Alfred Ossian    male  20.0
# 877                               Petroff, Mr. Nedelio    male  19.0
# 878                                 Laleff, Mr. Kristo    male   NaN
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0
# 881                                 Markun, Mr. Johann    male  33.0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0
# 883                      Banfield, Mr. Frederick James    male  28.0
# 884                             Sutehall, Mr. Henry Jr    male  25.0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
#          Fare      Embarked   Title  Age2
# 0      7.2500  Southhampton      Mr  22.0
# 1     71.2833     Cherbourg     Mrs  38.0
# 2      7.9250  Southhampton    Miss  26.0
# 3     53.1000  Southhampton     Mrs  35.0
# 4      8.0500  Southhampton      Mr  35.0
# 5      8.4583    Queenstown      Mr  30.0
# 6     51.8625  Southhampton      Mr  54.0
# 7     21.0750  Southhampton  Master   2.0
# 8     11.1333  Southhampton     Mrs  27.0
# 9     30.0708     Cherbourg     Mrs  14.0
# 10    16.7000  Southhampton    Miss   4.0
# 11    26.5500  Southhampton    Miss  58.0
# 12     8.0500  Southhampton      Mr  20.0
# 13    31.2750  Southhampton      Mr  39.0
# 14     7.8542  Southhampton    Miss  14.0
# 15    16.0000  Southhampton     Mrs  55.0
# 16    29.1250    Queenstown  Master   2.0
# 17    13.0000  Southhampton      Mr  30.0
# 18    18.0000  Southhampton     Mrs  31.0
# 19     7.2250     Cherbourg     Mrs  35.0
# 20    26.0000  Southhampton      Mr  35.0
# 21    13.0000  Southhampton      Mr  34.0
# 22     8.0292    Queenstown    Miss  15.0
# 23    35.5000  Southhampton      Mr  28.0
# 24    21.0750  Southhampton    Miss   8.0
# 25    31.3875  Southhampton     Mrs  38.0
# 26     7.2250     Cherbourg      Mr  30.0
# 27   263.0000  Southhampton      Mr  19.0
# 28     7.8792    Queenstown    Miss  21.0
# 29     7.8958  Southhampton      Mr  30.0
# ..        ...           ...     ...   ...
# 861   11.5000  Southhampton      Mr  21.0
# 862   25.9292  Southhampton     Mrs  48.0
# 863   69.5500  Southhampton    Miss  21.0
# 864   13.0000  Southhampton      Mr  24.0
# 865   13.0000  Southhampton     Mrs  42.0
# 866   13.8583     Cherbourg    Miss  27.0
# 867   50.4958  Southhampton      Mr  31.0
# 868    9.5000  Southhampton      Mr  30.0
# 869   11.1333  Southhampton  Master   4.0
# 870    7.8958  Southhampton      Mr  26.0
# 871   52.5542  Southhampton     Mrs  47.0
# 872    5.0000  Southhampton      Mr  33.0
# 873    9.0000  Southhampton      Mr  47.0
# 874   24.0000     Cherbourg     Mrs  28.0
# 875    7.2250     Cherbourg    Miss  15.0
# 876    9.8458  Southhampton      Mr  20.0
# 877    7.8958  Southhampton      Mr  19.0
# 878    7.8958  Southhampton      Mr  30.0
# 879   83.1583     Cherbourg     Mrs  56.0
# 880   26.0000  Southhampton     Mrs  25.0
# 881    7.8958  Southhampton      Mr  33.0
# 882   10.5167  Southhampton    Miss  22.0
# 883   10.5000  Southhampton      Mr  28.0
# 884    7.0500  Southhampton      Mr  25.0
# 885   29.1250    Queenstown     Mrs  39.0
# 886   13.0000  Southhampton          27.0
# 887   30.0000  Southhampton    Miss  19.0
# 888   23.4500  Southhampton    Miss  21.0
# 889   30.0000     Cherbourg      Mr  26.0
# 890    7.7500    Queenstown      Mr  32.0
#
# [891 rows x 10 columns]

# %% [markdown]
# ## 5. 이상치를 다루는 방법

# %%
# titanic 데이터를 가져옵니다.

ti = pd.read_csv(r'C:\Users\50008313\Python_Jupyter_Study\2기교육\5_데이터전처리와_EDA\샘플데이터\titanic_simple.csv', engine = 'python')

# %%
ti.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age     Fare  \
# 0                            Braund, Mr. Owen Harris    male  22.0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                             Heikkinen, Miss. Laina  female  26.0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                           Allen, Mr. William Henry    male  35.0   8.0500
#
#        Embarked
# 0  Southhampton
# 1     Cherbourg
# 2  Southhampton
# 3  Southhampton
# 4  Southhampton

# %% [markdown]
# #### 연속형 변수인 Age에 대해서 살펴봅시다.

# %% [markdown]
# ### 5.1 Age에 대한 차트와 기초 통계량을 살펴봅시다.

# %%
import seaborn as sns

# %%
sns.boxplot( y="Age", data=ti, orient = 'h')

# %%
ti['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
sns.distplot(ti[ti["Age"].notnull()]["Age"], rug = True)
# Out:
# C:\Users\50008313\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### 5.2 IQR을 이용한 방식으로 이상치를 구별해 봅시다.

# %%
q1 = ti['Age'].quantile(.25)
q3 = ti['Age'].quantile(.75)

iqr = q3-q1

# %%
min_iqr = q1 - 1.5 * iqr
max_iqr = q3 + 1.5 * iqr
print(min_iqr, max_iqr)
# Out:
# -6.6875 64.8125

# %% [markdown]
# min_iqr과 max_iqr이 실제 min ~ max 범위를 벗어날 수는 없습니다.
# 그러므로 만약 min_iqr < min 이라면 min_iqr은 min의 값으로 대체되어야 합니다.

# %%
min_from_all = ti['Age'].min()
max_from_all = ti['Age'].max()

# %%
# ti['Age'].describe().loc['min']

# %%
if (min_iqr < min_from_all) :
    min_iqr = min_from_all
if (max_iqr > max_from_all) :
    max_iqr = max_from_all
print(min_iqr, max_iqr)
# Out:
# 0.42 64.8125

# %% [markdown]
# #### 이제 min_iqr ~ max_iqr 범위 밖의 데이터를 조회해 봅시다.

# %%
(ti['Age'] < min_iqr ) | (ti['Age'] > max_iqr)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 861    False
# 862    False
# 863    False
# 864    False
# 865    False
# 866    False
# 867    False
# 868    False
# 869    False
# 870    False
# 871    False
# 872    False
# 873    False
# 874    False
# 875    False
# 876    False
# 877    False
# 878    False
# 879    False
# 880    False
# 881    False
# 882    False
# 883    False
# 884    False
# 885    False
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
ti[(ti['Age'] < min_iqr ) | (ti['Age'] > max_iqr)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 280          281         0       3                      Duane, Mr. Frank
# 456          457         0       1             Millet, Mr. Francis Davis
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age     Fare      Embarked
# 33   male  66.0  10.5000  Southhampton
# 54   male  65.0  61.9792     Cherbourg
# 96   male  71.0  34.6542     Cherbourg
# 116  male  70.5   7.7500    Queenstown
# 280  male  65.0   7.7500    Queenstown
# 456  male  65.0  26.5500  Southhampton
# 493  male  71.0  49.5042     Cherbourg
# 630  male  80.0  30.0000  Southhampton
# 672  male  70.0  10.5000  Southhampton
# 745  male  70.0  71.0000  Southhampton
# 851  male  74.0   7.7750  Southhampton

# %% [markdown]
# * 이들의 나이는 이상치인가요?

# %%
ti.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Fare',
#        'Embarked'],
#       dtype='object')

# %% [markdown]
# ### 실습 : Fare에 대해서 이상치를 판별해 보시오.

# %%
# 1) 박스플롯과 히스토그램으로 이상치인지 살펴 보세요.
sns.boxplot(y ='Fare', data = ti, orient = 'h')

# %%
sns.distplot(ti[ti["Fare"].notnull()]["Fare"], rug = True)

# %%
# 2) IQR 방식을 이용하여 이상치인 사람들의 정보를 조회하시오.

q1 = ti['Fare'].quantile(.25)
q3 = ti['Fare'].quantile(.75)
iqr = q3-q1
min_iqr = q1 - 1.5 * iqr
max_iqr = q3 + 1.5 * iqr
min_from_all = ti['Fare'].min()
max_from_all = ti['Fare'].max()
if (min_iqr < min_from_all) :
    min_iqr = min_from_all
if (max_iqr > max_from_all) :
    max_iqr = max_from_all

ti[(ti['Fare'] < min_iqr ) | (ti['Fare'] > max_iqr)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 27            28         0       1
# 31            32         1       1
# 34            35         0       1
# 52            53         1       1
# 61            62         1       1
# 62            63         0       1
# 72            73         0       2
# 88            89         1       1
# 102          103         0       1
# 118          119         0       1
# 120          121         0       2
# 124          125         0       1
# 139          140         0       1
# 151          152         1       1
# 159          160         0       3
# 180          181         0       3
# 195          196         1       1
# 201          202         0       3
# 215          216         1       1
# 218          219         1       1
# 224          225         1       1
# 230          231         1       1
# 245          246         0       1
# 256          257         1       1
# 257          258         1       1
# 258          259         1       1
# 262          263         0       1
# 268          269         1       1
# 269          270         1       1
# ..           ...       ...     ...
# 659          660         0       1
# 660          661         1       1
# 665          666         0       2
# 679          680         1       1
# 681          682         1       1
# 689          690         1       1
# 698          699         0       1
# 700          701         1       1
# 708          709         1       1
# 716          717         1       1
# 730          731         1       1
# 737          738         1       1
# 741          742         0       1
# 742          743         1       1
# 745          746         0       1
# 759          760         1       1
# 763          764         1       1
# 765          766         1       1
# 779          780         1       1
# 789          790         0       1
# 792          793         0       3
# 802          803         1       1
# 820          821         1       1
# 829          830         1       1
# 835          836         1       1
# 846          847         0       3
# 849          850         1       1
# 856          857         1       1
# 863          864         0       3
# 879          880         1       1
#
#                                                   Name     Sex   Age  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 27                      Fortune, Mr. Charles Alexander    male  19.0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN
# 34                             Meyer, Mr. Edgar Joseph    male  28.0
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0
# 61                                 Icard, Miss. Amelie  female  38.0
# 62                         Harris, Mr. Henry Birkhardt    male  45.0
# 72                                Hood, Mr. Ambrose Jr    male  21.0
# 88                          Fortune, Miss. Mabel Helen  female  23.0
# 102                          White, Mr. Richard Frasar    male  21.0
# 118                           Baxter, Mr. Quigg Edmond    male  24.0
# 120                        Hickman, Mr. Stanley George    male  21.0
# 124                        White, Mr. Percival Wayland    male  54.0
# 139                                 Giglio, Mr. Victor    male  24.0
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0
# 159                         Sage, Master. Thomas Henry    male   NaN
# 180                       Sage, Miss. Constance Gladys  female   NaN
# 195                               Lurette, Miss. Elise  female  58.0
# 201                                Sage, Mr. Frederick    male   NaN
# 215                            Newell, Miss. Madeleine  female  31.0
# 218                              Bazzani, Miss. Albina  female  32.0
# 224                       Hoyt, Mr. Frederick Maxfield    male  38.0
# 230       Harris, Mrs. Henry Birkhardt (Irene Wallach)  female  35.0
# 245                        Minahan, Dr. William Edward    male  44.0
# 256                     Thorne, Mrs. Gertrude Maybelle  female   NaN
# 257                               Cherry, Miss. Gladys  female  30.0
# 258                                   Ward, Miss. Anna  female  35.0
# 262                                  Taussig, Mr. Emil    male  52.0
# 268      Graham, Mrs. William Thompson (Edith Junkins)  female  58.0
# 269                             Bissette, Miss. Amelia  female  35.0
# ..                                                 ...     ...   ...
# 659                         Newell, Mr. Arthur Webster    male  58.0
# 660                      Frauenthal, Dr. Henry William    male  50.0
# 665                                 Hickman, Mr. Lewis    male  32.0
# 679                 Cardeza, Mr. Thomas Drake Martinez    male  36.0
# 681                                 Hassab, Mr. Hammad    male  27.0
# 689                  Madill, Miss. Georgette Alexandra  female  15.0
# 698                           Thayer, Mr. John Borland    male  49.0
# 700  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0
# 708                               Cleaver, Miss. Alice  female  22.0
# 716                      Endres, Miss. Caroline Louise  female  38.0
# 730                      Allen, Miss. Elisabeth Walton  female  29.0
# 737                             Lesurer, Mr. Gustave J    male  35.0
# 741                      Cavendish, Mr. Tyrell William    male  36.0
# 742              Ryerson, Miss. Susan Parker "Suzette"  female  21.0
# 745                       Crosby, Capt. Edward Gifford    male  70.0
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.0
# 763          Carter, Mrs. William Ernest (Lucile Polk)  female  36.0
# 765               Hogeboom, Mrs. John C (Anna Andrews)  female  51.0
# 779  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...  female  43.0
# 789                           Guggenheim, Mr. Benjamin    male  46.0
# 792                            Sage, Miss. Stella Anna  female   NaN
# 802                Carter, Master. William Thornton II    male  11.0
# 820  Hays, Mrs. Charles Melville (Clara Jennings Gr...  female  52.0
# 829          Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0
# 835                        Compton, Miss. Sara Rebecca  female  39.0
# 846                           Sage, Mr. Douglas Bullen    male   NaN
# 849       Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female   NaN
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0
#
#          Fare      Embarked
# 1     71.2833     Cherbourg
# 27   263.0000  Southhampton
# 31   146.5208     Cherbourg
# 34    82.1708     Cherbourg
# 52    76.7292     Cherbourg
# 61    80.0000           NaN
# 62    83.4750  Southhampton
# 72    73.5000  Southhampton
# 88   263.0000  Southhampton
# 102   77.2875  Southhampton
# 118  247.5208     Cherbourg
# 120   73.5000  Southhampton
# 124   77.2875  Southhampton
# 139   79.2000     Cherbourg
# 151   66.6000  Southhampton
# 159   69.5500  Southhampton
# 180   69.5500  Southhampton
# 195  146.5208     Cherbourg
# 201   69.5500  Southhampton
# 215  113.2750     Cherbourg
# 218   76.2917     Cherbourg
# 224   90.0000  Southhampton
# 230   83.4750  Southhampton
# 245   90.0000    Queenstown
# 256   79.2000     Cherbourg
# 257   86.5000  Southhampton
# 258  512.3292     Cherbourg
# 262   79.6500  Southhampton
# 268  153.4625  Southhampton
# 269  135.6333  Southhampton
# ..        ...           ...
# 659  113.2750     Cherbourg
# 660  133.6500  Southhampton
# 665   73.5000  Southhampton
# 679  512.3292     Cherbourg
# 681   76.7292     Cherbourg
# 689  211.3375  Southhampton
# 698  110.8833     Cherbourg
# 700  227.5250     Cherbourg
# 708  151.5500  Southhampton
# 716  227.5250     Cherbourg
# 730  211.3375  Southhampton
# 737  512.3292     Cherbourg
# 741   78.8500  Southhampton
# 742  262.3750     Cherbourg
# 745   71.0000  Southhampton
# 759   86.5000  Southhampton
# 763  120.0000  Southhampton
# 765   77.9583  Southhampton
# 779  211.3375  Southhampton
# 789   79.2000     Cherbourg
# 792   69.5500  Southhampton
# 802  120.0000  Southhampton
# 820   93.5000  Southhampton
# 829   80.0000           NaN
# 835   83.1583     Cherbourg
# 846   69.5500  Southhampton
# 849   89.1042     Cherbourg
# 856  164.8667  Southhampton
# 863   69.5500  Southhampton
# 879   83.1583     Cherbourg
#
# [116 rows x 8 columns]

# %%
# 3) 위 1,2번 방식으로 볼 때 이상치를 어떻게 처리하는게 좋을까요?
# 의견과, 그렇게 생각한 이유를 적어봅니다.
# 그리고 자신의 의견대로 이상치를 처리해 봅니다.
# 단 이상치 처리를 위해 기존 Fare를 복사해서 Fare2를 만들고 Fare2에 적용해 봅니다.

ti['Fare2'] = ti['Fare']

# %%
ti.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age     Fare  \
# 0                            Braund, Mr. Owen Harris    male  22.0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                             Heikkinen, Miss. Laina  female  26.0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                           Allen, Mr. William Henry    male  35.0   8.0500
#
#        Embarked    Fare2
# 0  Southhampton   7.2500
# 1     Cherbourg  71.2833
# 2  Southhampton   7.9250
# 3  Southhampton  53.1000
# 4  Southhampton   8.0500
